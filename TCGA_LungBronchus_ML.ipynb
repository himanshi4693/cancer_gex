# %%
import pandas as pd

# %%
lung_df = pd.read_csv('wide_lung_gex_clinical.csv')
lung_df.head()
# Out:
# /var/folders/xr/b__dtky94kv9txzqq5nvxq8h0000gn/T/ipykernel_71615/1811087752.py:1: DtypeWarning: Columns (58298,58300,58303,58310,58311) have mixed types. Specify dtype option on import or set low_memory=False.
#   lung_df = pd.read_csv('wide_lung_gex_clinical.csv')
#    Unnamed: 0                         cases.case_id  \
# 0           0  003f4f85-3244-4132-8c9d-c29f09382269
# 1           1  003f4f85-3244-4132-8c9d-c29f09382269
# 2           2  005669e5-1a31-45fb-ae97-9d450e74e7cb
# 3           3  005669e5-1a31-45fb-ae97-9d450e74e7cb
# 4           4  006931bb-f5b1-4aa4-b0a8-af517a912db0
#
#                               file_name               cases.samples.sample_id  \
# 0  514aa2ae-6c49-4b89-9a44-0f87a80bf77f  ca05dbf9-803c-4019-b79c-1a6c5a9d85d5
# 1  d09e76b4-f980-4b9c-a9e1-e97b60e26950  63824d8d-425b-4ec8-ae7e-16920db41523
# 2  6a994238-296a-4047-a8d4-e2eed5dd7bfc  a007ecae-0f53-4523-a9b3-8865ed7cf614
# 3  6a994238-296a-4047-a8d4-e2eed5dd7bfc  a007ecae-0f53-4523-a9b3-8865ed7cf614
# ...

# %%
# Display all column names in the DataFrame
for idx, col in enumerate(lung_df.columns, start=1):
    if col.startswith('ENSG'):
        continue
    else:
        print(f"{idx}: {col}")
# Out:
# 1: Unnamed: 0
# 2: cases.case_id
# 3: file_name
# 4: cases.samples.sample_id
# 5: cases.samples.sample_type
# 58288: id
# 58289: case_id
# 58290: demographic.race
# 58291: demographic.gender
# 58292: demographic.ethnicity
# 58293: demographic.vital_status
# 58294: diagnoses.tissue_or_organ_of_origin
# 58295: diagnoses.age_at_diagnosis
# 58296: diagnoses.primary_diagnosis
# 58297: diagnoses.site_of_resection_or_biopsy
# 58298: diagnoses.days_to_last_follow_up
# 58299: diagnoses.prior_malignancy
# 58300: diagnoses.year_of_diagnosis
# 58301: diagnoses.prior_treatment
# 58302: diagnoses.days_to_last_known_disease_status
# 58303: diagnoses.tumor_grade
# 58304: exposures.tobacco_smoking_status
# 58305: exposures.alcohol_history
# 58306: files.file_name
# 58307: files.file_id
# 58308: updated_datetime
# 58309: treatment_id
# 58310: treatment_type
# 58311: therapeutic_agents
# 58312: treatment_or_therapy
# 58313: state
# 58314: created_datetime

# %%
lung_df = lung_df.drop(columns=[''])
# Out:
# (3575, 58314)

# %%
# idea : use top genes from EDA, do EFA to identify factors?
# ML models :
